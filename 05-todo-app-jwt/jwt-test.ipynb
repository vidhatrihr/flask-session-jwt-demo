# %%
import sys
if 'jwt' in sys.modules:
  del sys.modules['jwt']

# %%
import time
from jwt import *

# %%
assert b64url_decode(b64url_encode(b'a')) == b'a'
assert b64url_decode(b64url_encode(b'ab')) == b'ab'
assert b64url_decode(b64url_encode(b'abc')) == b'abc'
assert b64url_decode(b64url_encode(b'abcd')) == b'abcd'

# %%
sign(b'hello')
# Out:
# '2J2h0FbNhfFfXBHTGcX6-YGYSQRA8yjFXB6oSbPkw80'

# %%
token = jwt_encode({
    'sub': 1,
    'iat': int(time.time())
})

token
# Out:
# 'eyJhbGciOiAiSFMyNTYiLCAidHlwIjogIkpXVCJ9.eyJzdWIiOiAxLCAiaWF0IjogMTc2OTMyNjM1NH0.Ga8KjLP4fjm0I5BNHadm69KAhX9IYSen0Eyg8-H0kw0'

# %%
jwt_decode(token)
# Out:
# {'sub': 1, 'iat': 1769326354}
