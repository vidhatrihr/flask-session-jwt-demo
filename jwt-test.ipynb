# %%
import sys
if 'jwt' in sys.modules:
  del sys.modules['jwt']

# %%
from jwt import *

# %%
encoded = b64url_encode(b'abcdefg')
b64url_decode(encoded)
# Out:
# b'abcdefg'

# %%
sign(b'hello')
# Out:
# '5qldZn04m3HBR83kEZPMwxA0toG6S4NA6gTQJgnrjnk'

# %%
token = jwt_encode({
    'sub': 1,
    'iat': int(time.time())
})

token
# Out:
# 'eyJhbGciOiAiSFMyNTYiLCAidHlwIjogIkpXVCJ9.eyJzdWIiOiAxLCAiaWF0IjogMTc2ODIyOTU3Nn0.ATaFRJgkbc5g-72seNPq-MGoWwHxWVK7U84Vq88iWQs'

# %%
jwt_decode(token)
# Out:
# {'sub': 1, 'iat': 1768229576}
